# %%
# !pip install pyautogen openai cohere tiktoken --upgrade
# Out:
# ...
#   Using cached openai-1.3.5-py3-none-any.whl (220 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 941.0 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 62.7 MB/s eta 0:00:00
# ...

# %%
import autogen

config_list = [
    {
        "model": "gpt-4-1106-preview",
        "api_key": "openai-api-key"
    }
]

llm_config = {
    "request_timeout": 600,
    "seed": 42,
    "config_list": config_list,
    "temperature": 0
}

# %%
assistant = autogen.AssistantAgent(
    name = "Math tutor",
    llm_config = llm_config,
    system_message = "Expert math professeur in a big University"
)

user_proxy = autogen.UserProxyAgent(
    name = "user_proxy",
    human_input_mode = "NEVER",
    max_consecutive_auto_reply = 10,
    # is_termination_msg=lambda x: x.get("content", "") and x.get("content", "").rstrip().endswith("TERMINATE"),
    # code_execution_config = {'working_dir': 'web'},
    llm_config = llm_config,
)

# %%
math_problem = "Find all $x$ that satisfy the inequality $(2x+10)(x+3)<(3x+9)(x+8)$. Express your answer in interval notation."
user_proxy.initiate_chat(
  assistant,
  message = math_problem
)
# Out:
# user_proxy (to Math tutor):
#
# Find all $x$ that satisfy the inequality $(2x+10)(x+3)<(3x+9)(x+8)$. Express your answer in interval notation.
#
# --------------------------------------------------------------------------------
# Math tutor (to user_proxy):
#
# To find all $x$ that satisfy the inequality $(2x+10)(x+3)<(3x+9)(x+8)$, we first expand both sides of the inequality:
#
# Left side: $(2x+10)(x+3) = 2x^2 + 6x + 10x + 30 = 2x^2 + 16x + 30$
# Right side: $(3x+9)(x+8) = 3x^2 + 24x + 9x + 72 = 3x^2 + 33x + 72$
#
# Now, we rewrite the inequality with the expanded terms:
#
# $2x^2 + 16x + 30 < 3x^2 + 33x + 72$
#
# Next, we move all terms to one side to set the inequality to zero:
#
# $2x^2 + 16x + 30 - 3x^2 - 33x - 72 < 0$
#
# Simplify the inequality:
#
# $-x^2 - 17x - 42 < 0$
#
# Now, we factor the quadratic expression:
#
# $-(x^2 + 17x + 42) < 0$
#
# Factor the quadratic:
#
# $-(x + 7)(x + 6) < 0$
#
# ...

# %%
math_problem = "For what negative value of $k$ is there exactly one solution to the system of equations \\begin{align*}\ny &= 2x^2 + kx + 6 \\\\\ny &= -x + 4?\n\\end{align*}"
user_proxy.initiate_chat(
  assistant,
  message = math_problem
)
# Out:
# user_proxy (to Math tutor):
#
# For what negative value of $k$ is there exactly one solution to the system of equations \begin{align*}
# y &= 2x^2 + kx + 6 \\
# y &= -x + 4?
# \end{align*}
#
# --------------------------------------------------------------------------------
# Math tutor (to user_proxy):
#
# To find the value of $k$ for which there is exactly one solution to the system of equations, we need to set the two equations equal to each other and find the value of $k$ that makes the resulting quadratic equation have exactly one real root. This occurs when the discriminant of the quadratic equation is zero.
#
# The system of equations is:
# \begin{align*}
# y &= 2x^2 + kx + 6 \\
# y &= -x + 4
# \end{align*}
#
# Setting the right-hand sides of the equations equal to each other gives us:
# \begin{align*}
# 2x^2 + kx + 6 &= -x + 4
# \end{align*}
#
# Rearrange the equation to set it to zero:
# \begin{align*}
# 2x^2 + kx + 6 + x - 4 &= 0 \\
# 2x^2 + (k + 1)x + 2 &= 0
# \end{align*}
# ...
